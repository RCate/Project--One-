# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Name of the CSV file
file = 'listings.csv'
Airbnb_Austin_df = pd.read_csv(file)

# %%
Airbnb_Austin_df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0    72635    https://www.airbnb.com/rooms/72635  20151107173015   2015-11-08
# 1  5386323  https://www.airbnb.com/rooms/5386323  20151107173015   2015-11-07
# 2  8826517  https://www.airbnb.com/rooms/8826517  20151107173015   2015-11-07
# 3  8828616  https://www.airbnb.com/rooms/8828616  20151107173015   2015-11-08
# 4  8536913  https://www.airbnb.com/rooms/8536913  20151107173015   2015-11-08
#
#                              name  \
# 0   3 Private Bedrooms, SW Austin
# 1                 Cricket Trailer
# 2  Private room 1 in South Austin
# 3  Private room 2 in South Austin
# 4       Brand-New 3BR Austin Home
#
#                                              summary  \
# 0  Conveniently located 10-15 from downtown in SW...
# 1  Rent this cool concept trailer that has everyt...
# 2  Upstairs, private, 12ft x 13 1/2ft room.  Priv...
# 3  Upstairs, private, 11ft x 13 1/2ft room.  Priv...
# ...

# %%
Airbnb_Austin_df['price'] = Airbnb_Austin_df['price'].str.replace('$', '')
Airbnb_Austin_df['price'] = Airbnb_Austin_df['price'].str.replace(',', '')

# %%
Airbnb_Austin_df['price'] = pd.to_numeric(Airbnb_Austin_df['price'])

# %%
Airbnb_Price_df=pd.DataFrame(Airbnb_Austin_df)

# %%
# Airbnb_Austin_df['weekly_price'] = Airbnb_Austin_df['weekly_price'].str.replace('$', '')
# Airbnb_Austin_df['weekly_price'] = Airbnb_Austin_df['weekly_price'].str.replace(',', '')
# Airbnb_Austin_df['monthly_price'] = Airbnb_Austin_df['monthly_price'].str.replace('$', '')
# Airbnb_Austin_df['monthly_price'] = Airbnb_Austin_df['monthly_price'].str.replace(',', '')

# %%
# Airbnb_Austin_df['weekly_price'] = pd.to_numeric(Airbnb_Austin_df['weekly_price'])
# Airbnb_Austin_df['monthly_price'] = pd.to_numeric(Airbnb_Austin_df['monthly_price'])

# %%
Airbnb_Price_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
Airbnb_Austin_Data = Airbnb_Price_df[['summary', 'zipcode', 'property_type',
                                      'accommodates', 'bedrooms','bathrooms', 'beds', 'amenities',
                                      'square_feet', 'price', 'availability_365', 
                                      'cancellation_policy', 'review_scores_rating', 'review_scores_value','description',
                                     'instant_bookable','host_verifications']]

# %%
Airbnb_Austin_Data.head()
# Out:
#                                              summary  zipcode property_type  \
# 0  Conveniently located 10-15 from downtown in SW...  78749.0         House
# 1  Rent this cool concept trailer that has everyt...  78739.0     Camper/RV
# 2  Upstairs, private, 12ft x 13 1/2ft room.  Priv...  78739.0         House
# 3  Upstairs, private, 11ft x 13 1/2ft room.  Priv...  78739.0         House
# 4  Brand-new 3BR/2BA Austin home with landscaped ...  78739.0         House
#
#    accommodates  bedrooms  bathrooms  beds  \
# 0             6       1.0        2.5   3.0
# 1             2       1.0        0.0   1.0
# 2             2       1.0        1.5   1.0
# 3             2       1.0        1.5   1.0
# 4             6       3.0        2.0   3.0
#
#                                            amenities  square_feet  price  \
# 0  {"Cable TV",Internet,"Wireless Internet","Air ...       3600.0  300.0
# 1  {"Air Conditioning",Heating,"Family/Kid Friend...          NaN   99.0
# ...

# %%
Airbnb_Austin_Data.to_csv("Airbnb_Austin_Data_Finalized.csv", index=False, header=True)
