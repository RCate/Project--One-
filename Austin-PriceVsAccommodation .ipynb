# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_file = "Airbnb_Austin_Data_Finalized.csv"
abb_csv = pd.read_csv(csv_file)
abb_df = pd.DataFrame(abb_csv)
abb_df.head()
# Out:
#                                              summary  zipcode property_type  \
# 0  Conveniently located 10-15 from downtown in SW...  78749.0         House
# 1  Rent this cool concept trailer that has everyt...  78739.0     Camper/RV
# 2  Upstairs, private, 12ft x 13 1/2ft room.  Priv...  78739.0         House
# 3  Upstairs, private, 11ft x 13 1/2ft room.  Priv...  78739.0         House
# 4  Brand-new 3BR/2BA Austin home with landscaped ...  78739.0         House
#
#    accommodates  bedrooms  bathrooms  beds  \
# 0             6       1.0        2.5   3.0
# 1             2       1.0        0.0   1.0
# 2             2       1.0        1.5   1.0
# 3             2       1.0        1.5   1.0
# 4             6       3.0        2.0   3.0
#
#                                            amenities  square_feet  price  \
# 0  {"Cable TV",Internet,"Wireless Internet","Air ...       3600.0  300.0
# 1  {"Air Conditioning",Heating,"Family/Kid Friend...          NaN   99.0
# ...

# %%
price_per_accomm = abb_df["price"]/abb_df["accommodates"]

abb_df["price_per_accommodation"] = price_per_accomm
abb_df["price_per_accommodation"].median()
# Out:
# 47.5

# %%
accommodation_group = abb_df.groupby("accommodates")
accomm_group_median = accommodation_group.median()
accomm_group_median
# Out:
#               zipcode  bedrooms  bathrooms  beds  square_feet  price  \
# accommodates
# 1             78729.0       1.0       1.00   1.0        275.0   55.0
# 2             78722.0       1.0       1.00   1.0        600.0   95.0
# 3             78704.0       1.0       1.00   1.0        600.0  125.0
# 4             78704.0       1.0       1.00   2.0       1000.0  180.0
# 5             78704.0       2.0       1.00   2.0        960.0  220.0
# 6             78704.0       2.0       2.00   3.0       1425.0  299.0
# 7             78721.0       3.0       2.00   3.5       1500.0  350.0
# 8             78704.0       3.0       2.00   4.0       1768.5  450.0
# 9             78722.0       3.0       2.00   5.0       2200.0  399.0
# 10            78704.0       4.0       2.50   5.0       2675.0  525.0
# 11            78704.0       4.0       2.50   6.0       3000.0  759.0
# 12            78704.0       4.0       2.50   6.0       2500.0  500.0
# ...

# %%
y_axis = accomm_group_median["price_per_accommodation"]
x_axis = np.arange(len(y_axis))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, (x_axis+1))

#x_axis = range(len(abb_df["price_per_accommodation"]))
#x_axis = abb_df["price"]
#plt.scatter(x_axis, y_axis, marker="o", facecolors="red", 
#            s=0.1, alpha=0.75)
plt.bar(x_axis, y_axis, color="mediumaquamarine", align="center")
plt.title("Austin AirBnB - Price per Accommodation")
plt.xlabel("Accomodates")
plt.ylabel("Avg Price Per Accomodation ($)")
plt.show()

# %%
plt.savefig("AustinPriceVsAccommodationBarChart.png")
